# %% [markdown]
# <a href="https://colab.research.google.com/github/fishitmo/Takeobds/blob/main/Random_Forest_%26_SVM_01_31.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import io
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8ee6c4db-a4dd-4e59-9bc5-122d6e0af226" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8ee6c4db-a4dd-4e59-9bc5-122d6e0af226">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
filename = next(iter(uploaded))

# %%
df = pd.read_csv(filename, sep= '\t')
df.head()
# Out:
#   label                                            message  length  punct
# 0   ham  Go until jurong point, crazy.. Available only ...     111      9
# 1   ham                      Ok lar... Joking wif u oni...      29      6
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...     155      6
# 3   ham  U dun say so early hor... U c already then say...      49      6
# 4   ham  Nah I don't think he goes to usf, he lives aro...      61      2

# %%
df.isnull().sum()
# Out:
# label      0
# message    0
# length     0
# punct      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   label    5572 non-null   object
#  1   message  5572 non-null   object
#  2   length   5572 non-null   int64
#  3   punct    5572 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 174.2+ KB

# %%
df.head()
# Out:
#   label                                            message  length  punct
# 0   ham  Go until jurong point, crazy.. Available only ...     111      9
# 1   ham                      Ok lar... Joking wif u oni...      29      6
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...     155      6
# 3   ham  U dun say so early hor... U c already then say...      49      6
# 4   ham  Nah I don't think he goes to usf, he lives aro...      61      2

# %%
df.tail()
# Out:
#      label                                            message  length  punct
# 5567  spam  This is the 2nd time we have tried 2 contact u...     160      8
# 5568   ham               Will ü b going to esplanade fr home?      36      1
# 5569   ham  Pity, * was in mood for that. So...any other s...      57      7
# 5570   ham  The guy did some bitching but I acted like i'd...     125      1
# 5571   ham                         Rofl. Its true to its name      26      1

# %%
df.describe()
# Out:
#             length        punct
# count  5572.000000  5572.000000
# mean     80.489950     4.177495
# std      59.942907     4.623919
# min       2.000000     0.000000
# 25%      36.000000     2.000000
# 50%      62.000000     3.000000
# 75%     122.000000     6.000000
# max     910.000000   133.000000

# %%
df.label.value_counts()
# Out:
# ham     4825
# spam     747
# Name: label, dtype: int64

# %%
df.label.value_counts()/len(df)
# Out:
# ham     0.865937
# spam    0.134063
# Name: label, dtype: float64

# %%
ham = df[df.label=='ham']
spam = df[df.label=='spam']

# %%
ham.shape, spam.shape
# Out:
# ((4825, 4), (747, 4))

# %%
ham = ham.sample(spam.shape[0])

# %%
ham.shape, spam.shape
# Out:
# ((747, 4), (747, 4))

# %%
data = ham.append(spam, ignore_index=True)
# Out:
# <ipython-input-18-ea3b8d22737f>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = ham.append(spam, ignore_index=True)

# %%
data.shape
# Out:
# (1494, 4)

# %%
data['label'].value_counts()
# Out:
# ham     747
# spam    747
# Name: label, dtype: int64

# %%
data.head()
# Out:
#   label                                      message  length  punct
# 0   ham  Hey are we going for the lo lesson or gym?       43      1
# 1   ham                Ü takin linear algebra today?      29      1
# 2   ham      Thank you. And by the way, I just lost.      39      3
# 3   ham                     Hope you are not scared!      24      1
# 4   ham       No message..no responce..what happend?      38      5

# %%
data.tail()
# Out:
#      label                                            message  length  punct
# 1489  spam  Want explicit SEX in 30 secs? Ring 02073162414...      90      3
# 1490  spam  ASKED 3MOBILE IF 0870 CHATLINES INCLU IN FREE ...     158      5
# 1491  spam  Had your contract mobile 11 Mnths? Latest Moto...     160      8
# 1492  spam  REMINDER FROM O2: To get 2.50 pounds free call...     147      3
# 1493  spam  This is the 2nd time we have tried 2 contact u...     160      8

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test =  train_test_split(data['message'], data['label'], test_size = 0.3, random_state =0, shuffle = True)

# %%
X_train, X_test, y_train, y_test
# Out:
# (1438      You have 1 new message. Please call 08715205273
#  431     Wow so healthy. Old airport rd lor. Cant thk o...
#  194     Horrible gal. Me in sch doing some stuff. How ...
#  240     You only hate me. You can call any but you did...
#  1309    Had your mobile 11 months or more? U R entitle...
#                                ...
#  763     Your free ringtone is waiting to be collected....
#  835     XCLUSIVE@CLUBSAISAI 2MOROW 28/5 SOIREE SPECIAL...
#  1216    Dorothy@kiefer.com (Bank of Granite issues Str...
#  559     i cant talk to you now.i will call when i can....
#  684                          * Will be september by then!
#  Name: message, Length: 1045, dtype: object,
#  799     Ur cash-balance is currently 500 pounds - to m...
#  1047    FreeMsg: Hey - I'm Buffy. 25 and love to satis...
#  1436    TheMob>Hit the link to get a premium Pink Pant...
#  54                 Its ok., i just askd did u knw tht no?
#  793     Think ur smart ? Win £200 this week in our wee...
# ...

# %% [markdown]
# #**Building the Model (Random Forest)**

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline

# %%
classifier = Pipeline([("tfidf", TfidfVectorizer()) , ("classifier", RandomForestClassifier(n_estimators=100))])

# %%
classifier.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                 ('classifier', RandomForestClassifier())])

# %%
y_pred = classifier.predict(X_test)

# %%
y_test, y_pred
# Out:
# (799     spam
#  1047    spam
#  1436    spam
#  54       ham
#  793     spam
#          ...
#  824     spam
#  822     spam
#  644      ham
#  1034    spam
#  1356    spam
#  Name: label, Length: 449, dtype: object,
#  array(['spam', 'spam', 'spam', 'ham', 'spam', 'spam', 'ham', 'ham', 'ham',
#         'ham', 'spam', 'ham', 'ham', 'spam', 'spam', 'spam', 'spam', 'ham',
#         'ham', 'spam', 'spam', 'ham', 'spam', 'spam', 'ham', 'spam', 'ham',
#         'ham', 'spam', 'ham', 'ham', 'spam', 'spam', 'spam', 'spam',
#         'spam', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'spam', 'ham',
#         'ham', 'spam', 'ham', 'ham', 'spam', 'ham', 'ham', 'ham', 'ham',
#         'spam', 'spam', 'spam', 'ham', 'ham', 'spam', 'ham', 'ham', 'ham',
#         'ham', 'spam', 'spam', 'ham', 'ham', 'ham', 'spam', 'spam', 'spam',
#         'spam', 'spam', 'ham', 'ham', 'spam', 'spam', 'ham', 'ham', 'ham',
#         'spam', 'ham', 'ham', 'ham', 'ham', 'spam', 'spam', 'ham', 'spam',
# ...

# %%
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9354120267260579

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[224,   3],
#        [ 26, 196]])

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.90      0.99      0.94       227
#         spam       0.98      0.88      0.93       222
#
#     accuracy                           0.94       449
#    macro avg       0.94      0.93      0.94       449
# weighted avg       0.94      0.94      0.94       449

# %% [markdown]
# #**Building SVM Model**

# %%
from sklearn.svm import SVC

# %%
svm = Pipeline([("tfidf", TfidfVectorizer()) , ("classifier", SVC(C = 100, gamma='auto'))])

# %%
svm.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                 ('classifier', SVC(C=100, gamma='auto'))])

# %%
y_pred = svm.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9465478841870824

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[220,   7],
#        [ 17, 205]])

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.93      0.97      0.95       227
#         spam       0.97      0.92      0.94       222
#
#     accuracy                           0.95       449
#    macro avg       0.95      0.95      0.95       449
# weighted avg       0.95      0.95      0.95       449

# %%
test1 = ['Hello, You are learning natural Language Processing']
test2 = ['Hope you are doing good and learning new things !']
test3 = ['Congratulations, You won a lottery ticket worth $100 Million ! To claim call on 446677']

# %%
print(classifier.predict(test1))
print(classifier.predict(test2))
print(classifier.predict(test3))
# Out:
# ['ham']
# ['ham']
# ['spam']
